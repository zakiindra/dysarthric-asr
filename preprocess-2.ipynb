# %%
import collections
import contextlib
import sys
import wave
import os
import pandas as pd
import numpy as np
from pydub import AudioSegment

import webrtcvad


def read_wave(path):
    """Reads a .wav file.

    Takes the path, and returns (PCM audio data, sample rate).
    """
    with contextlib.closing(wave.open(path, 'rb')) as wf:
        num_channels = wf.getnchannels()
        assert num_channels == 1
        
        sample_width = wf.getsampwidth()
        assert sample_width == 2
        
        sample_rate = wf.getframerate()
        assert sample_rate in (8000, 16000, 32000, 48000)
        
        pcm_data = wf.readframes(wf.getnframes())
        return pcm_data, sample_rate


def write_wave(path, audio, sample_rate):
    """Writes a .wav file.

    Takes path, PCM audio data, and sample rate.
    """
    with contextlib.closing(wave.open(path, 'wb')) as wf:
        wf.setnchannels(1)
        wf.setsampwidth(2)
        wf.setframerate(sample_rate)
        wf.writeframes(audio)


class Frame(object):
    """Represents a "frame" of audio data."""
    def __init__(self, bytes, timestamp, duration):
        self.bytes = bytes
        self.timestamp = timestamp
        self.duration = duration


def frame_generator(frame_duration_ms, audio, sample_rate):
    """Generates audio frames from PCM audio data.

    Takes the desired frame duration in milliseconds, the PCM data, and
    the sample rate.

    Yields Frames of the requested duration.
    """
    n = int(sample_rate * (frame_duration_ms / 1000.0) * 2)
    offset = 0
    timestamp = 0.0
    duration = (float(n) / sample_rate) / 2.0
    while offset + n < len(audio):
        yield Frame(audio[offset:offset + n], timestamp, duration)
        timestamp += duration
        offset += n


def vad_collector(sample_rate, frame_duration_ms,
                  padding_duration_ms, vad, frames):
    """Filters out non-voiced audio frames.

    Given a webrtcvad.Vad and a source of audio frames, yields only
    the voiced audio.

    Uses a padded, sliding window algorithm over the audio frames.
    When more than 90% of the frames in the window are voiced (as
    reported by the VAD), the collector triggers and begins yielding
    audio frames. Then the collector waits until 90% of the frames in
    the window are unvoiced to detrigger.

    The window is padded at the front and back to provide a small
    amount of silence or the beginnings/endings of speech around the
    voiced frames.

    Arguments:

    sample_rate - The audio sample rate, in Hz.
    frame_duration_ms - The frame duration in milliseconds.
    padding_duration_ms - The amount to pad the window, in milliseconds.
    vad - An instance of webrtcvad.Vad.
    frames - a source of audio frames (sequence or generator).

    Returns: A generator that yields PCM audio data.
    """
    num_padding_frames = int(padding_duration_ms / frame_duration_ms)
    # We use a deque for our sliding window/ring buffer.
    ring_buffer = collections.deque(maxlen=num_padding_frames)
    # We have two states: TRIGGERED and NOTTRIGGERED. We start in the
    # NOTTRIGGERED state.
    triggered = False

    voiced_frames = []
    for frame in frames:
        is_speech = vad.is_speech(frame.bytes, sample_rate)

        # sys.stdout.write('1' if is_speech else '0')
        if not triggered:
            ring_buffer.append((frame, is_speech))
            num_voiced = len([f for f, speech in ring_buffer if speech])
            # If we're NOTTRIGGERED and more than 90% of the frames in
            # the ring buffer are voiced frames, then enter the
            # TRIGGERED state.
            if num_voiced > 0.9 * ring_buffer.maxlen:
                triggered = True
                # sys.stdout.write('+(%s)' % (ring_buffer[0][0].timestamp,))
                # We want to yield all the audio we see from now until
                # we are NOTTRIGGERED, but we have to start with the
                # audio that's already in the ring buffer.
                for f, s in ring_buffer:
                    voiced_frames.append(f)
                ring_buffer.clear()
        else:
            # We're in the TRIGGERED state, so collect the audio data
            # and add it to the ring buffer.
            voiced_frames.append(frame)
            ring_buffer.append((frame, is_speech))
            num_unvoiced = len([f for f, speech in ring_buffer if not speech])
            # If more than 90% of the frames in the ring buffer are
            # unvoiced, then enter NOTTRIGGERED and yield whatever
            # audio we've collected.
            if num_unvoiced > 0.9 * ring_buffer.maxlen:
                # sys.stdout.write('-(%s)' % (frame.timestamp + frame.duration))
                triggered = False
                yield b''.join([f.bytes for f in voiced_frames])
                ring_buffer.clear()
                voiced_frames = []
    # if triggered:
        # sys.stdout.write('-(%s)' % (frame.timestamp + frame.duration))
    # sys.stdout.write('\n')
    # If we have any leftover voiced audio when we run out of input,
    # yield it.
    if voiced_frames:
        yield b''.join([f.bytes for f in voiced_frames])

# %%
# noisered_path = "/data/zaki/UASpeech/audio/noisereduce"
# aggresiveness = 3

# failed = []
# for p in os.listdir(noisered_path):
#     output_dir = f"preprocess/{p}"
#     os.makedirs(output_dir, exist_ok=True)
#     for f in os.listdir(f"{noisered_path}/{p}"):
#         if not f.endswith('.wav') or f.startswith("._"):
#             continue
        
#         vad = webrtcvad.Vad(aggresiveness)
#         input_path = f"{noisered_path}/{p}/{f}"
#         audio, sample_rate = read_wave(input_path)
#         frames = frame_generator(30, audio, sample_rate)
#         frames = list(frames)
#         segment = list(vad_collector(sample_rate, 30, 300, vad, frames))
        
#         if len(segment) != 1:
#             failed.append((input_path, len(segment)))
#             # print(input_path, len(segment))
#             continue

#         output_path = f"{output_dir}/{f}"
#         write_wave(output_path, segment[0], sample_rate)
#     print(f"{output_dir} DONE")
# Out:
# preprocess/M12 DONE
# preprocess/CM12 DONE
# preprocess/F03 DONE
# preprocess/CF02 DONE
# preprocess/CM05 DONE
# preprocess/CM10 DONE
# preprocess/M11 DONE
# preprocess/M14 DONE
# preprocess/M07 DONE
# preprocess/CM13 DONE
# preprocess/M16 DONE
# preprocess/F02 DONE
# preprocess/CM01 DONE
# preprocess/CF04 DONE
# preprocess/M10 DONE
# preprocess/F05 DONE
# preprocess/CM08 DONE
# preprocess/CM09 DONE
# preprocess/M04 DONE
# preprocess/CF05 DONE
# preprocess/M08 DONE
# preprocess/F04 DONE
# preprocess/CM06 DONE
# preprocess/CM04 DONE
# preprocess/M01 DONE
# preprocess/CF03 DONE
# preprocess/M09 DONE
# preprocess/M05 DONE

# %%
# with open("failed_2.csv", "w") as ff:
#     for x in sorted(failed):
#         f, sc = x
#         ff.write(f"{f},{sc}\n")

# with open("failed_2_cnt.csv", "w") as ff:
#     for k,v in cnt.items():
#         ff.write(f"{k},{v}\n")

# %%
def process(input_path, output_path, aggresiveness):
    vad = webrtcvad.Vad(aggresiveness)
    audio, sample_rate = read_wave(input_path)
    frames = frame_generator(30, audio, sample_rate)
    frames = list(frames)
    segments = list(vad_collector(sample_rate, 30, 300, vad, frames))
    print(len(segments))
    # print(segments)
    return segments
    # if len(segment) != 1:
    #     print(input_path)
    #     return
    # for i, segment in enumerate(segments):
    #     path = output_path
    #     print(' Writing %s' % (path,))
    #     write_wave(path, segment, sample_rate)

file_path = "/data/zaki/UASpeech/audio/noisereduce/F04/F04_B3_CW30_M4.wav"
output_path = "chunk6-00.wav"
aggresiveness = 3


segments = process(file_path, output_path, aggresiveness)

for s in segments:
    audio = AudioSegment(data=s, sample_width=2, frame_rate=16000, channels=1)
    r = audio.get_array_of_samples()
    d = audio.duration_seconds
    print(len(r), d)
    
# audio = AudioSegment(data=segments[0], sample_width=2, frame_rate=16000, channels=1)
audio = AudioSegment(data=segments[1], sample_width=2, frame_rate=16000, channels=1)
# audio = AudioSegment(data=segments[2], sample_width=2, frame_rate=16000, channels=1)
# audio = AudioSegment(data=segments[3], sample_width=2, frame_rate=16000, channels=1)
# audio = AudioSegment.from_file(file_path)
# print(len(audio.get_array_of_samples()))
# print(len(audio))
# print(audio.duration_seconds)
audio
# Out:
# 2
# 15360 0.96
# 12000 0.75
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
pc = {}
sc = {}
pwc = {}
for f, c in sorted(dict(failed).items()):
    split = f.replace(noisered_path, "").split("/")

    p = split[1]
    sc[c] = 1 if sc.get(c, None) is None else sc[c] + 1
    pc[p] = 1 if pc.get(p, None) is None else pc[p] + 1
    
print(sorted(pc.items()))
print(sc)
# Out:
# [('CF02', 115), ('CF03', 136), ('CF04', 340), ('CF05', 43), ('CM01', 440), ('CM04', 616), ('CM05', 85), ('CM06', 32), ('CM08', 12), ('CM09', 43), ('CM10', 152), ('CM12', 102), ('CM13', 12), ('F02', 1906), ('F03', 544), ('F04', 302), ('F05', 157), ('M01', 1176), ('M04', 74), ('M05', 383), ('M07', 402), ('M08', 211), ('M09', 81), ('M10', 22), ('M11', 255), ('M12', 1476), ('M14', 151), ('M16', 303)]
# {2: 7376, 0: 331, 3: 1094, 7: 53, 5: 153, 6: 73, 4: 353, 8: 63, 9: 43, 11: 6, 10: 10, 17: 4, 18: 4, 16: 1, 12: 1, 19: 2, 15: 2, 21: 1, 20: 1}

# %%
pwc = {}
for f, c in sorted(dict(failed).items()):
    # if "/M12_B3_UW56" in f:
    #     print(f, c)
    
    if  c != 2:
        continue
    p, x = f.replace(noisered_path, "").split("/")[1:3]
    
    ss = x.replace(p, "").split("_")
    pw = f"{ss[1]}_{ss[2]}"
    if pwc.get(p, None) is None:
        pwc[p] = {
            pw: [c]
        }
    else:
        if pwc[p].get(pw, None) is None:
            pwc[p][pw] = [c]
        else:
            pwc[p][pw].append(c)

for k, v in pwc.items():
    for kk, vv in v.items():
        # if len(vv) > 1:
            print(k + "_" + kk, len(vv))

# %%
len(os.listdir("/data/zaki/UASpeech/audio/noisereduce/M12"))
# Out:
# 4590

# %% [markdown]
# Exclusion 1: Segments more than 3

# %%
# with open("exclude_path.csv", "w") as ff:
#     excluded = [f for f, c in sorted(dict(failed).items()) if c >= 10]
#     ff.write("\n".join(excluded))

# %% [markdown]
# Preprocess 0, 2, 3 segments:
# - Try 10 times for each aggressiveness 3,2,1
# - If produce 1 segment, return the segment
# - If produce 0 segment

# %%
import shutil

def process_with_retry(input_path):
    aggresiveness = 3
    rep = 10

    segment_map = {}
    while aggresiveness > 0:
        while rep > 0:
            vad = webrtcvad.Vad(aggresiveness)
            audio, sample_rate = read_wave(input_path)
            frames = frame_generator(30, audio, sample_rate)
            frames = list(frames)
            segment = list(vad_collector(sample_rate, 30, 300, vad, frames))

            if len(segment) == 1:
                return segment, sample_rate
            if len(segment) not in segment_map.keys():
                segment_map[len(segment)] = segment

            rep -= 1
        aggresiveness -= 1
            
    min_len = min(segment_map.keys())
    return segment_map[min_len], sample_rate
            
failed_retry = []
for f, c in sorted(dict(failed).items()):
    if c > 3:
        continue

    segment, sample_rate = process_with_retry(f)
    
    split = f.replace(noisered_path, "").split("/")
    p = split[1]
    output_dir = f"preprocess-failed/{p}"
    os.makedirs(output_dir, exist_ok=True)


    if len(segment) == 1:
        output_path = f"{output_dir}/{split[2]}"
        write_wave(output_path, segment[0], sample_rate)
    elif len(segment) == 0:
        try:
            shutil.copy2(f, output_dir)
        except Exception as e:
            failed_retry.append((f, len(segment)))
    elif len(segment) == 2:
        failed_retry.append((f, len(segment)))
        audio1 = AudioSegment(data=segment[0], sample_width=2, frame_rate=16000, channels=1)
        audio2 = AudioSegment(data=segment[1], sample_width=2, frame_rate=16000, channels=1)

        os.makedirs(f"preprocess-failed-2/{p}", exist_ok=True)
        output_path = f"preprocess-failed-2/{p}/{split[2]}"
        if audio1.duration_seconds > audio2.duration_seconds:
            write_wave(output_path, segment[0], sample_rate)
        else:
            write_wave(output_path, segment[1], sample_rate)
    elif len(segment) > 2:
        failed_retry.append((f, len(segment)))

    print(f"Processed {split[2]}: {len(segment)}")

# %%
file_path = "/data/zaki/UASpeech/preprocess-failed-2/M11/M11_B1_CW89_M7.wav"
audio1 = AudioSegment.from_file(file_path)
# print(audio1.duration_seconds)
# file_path = "/data/zaki/UASpeech/preprocess-failed-2/F04/F04_B3_CW30_M3.wav"
# audio2 = AudioSegment.from_file(file_path)
# print(audio2.duration_seconds)
# file_path = "/data/zaki/UASpeech/preprocess-failed-2/F04/F04_B3_CW30_M5.wav"
# audio3 = AudioSegment.from_file(file_path)
# print(audio3.duration_seconds)
# file_path = "/data/zaki/UASpeech/preprocess-failed-2/F04/F04_B3_CW30_M7.wav"
# audio4 = AudioSegment.from_file(file_path)
# print(audio4.duration_seconds)
# file_path = "/data/zaki/UASpeech/preprocess-failed-2/F04/F04_B3_CW30_M8.wav"
# audio5 = AudioSegment.from_file(file_path)
# print(audio5.duration_seconds)
audio1
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
dir = "preprocess-failed-2"
files = []
durations = []
for p in os.listdir(dir):
    for f in os.listdir(f"{dir}/{p}"):
        durations.append(AudioSegment.from_file(f"{dir}/{p}/{f}").duration_seconds)
        files.append(f)

# %%
np.min(durations), np.max(durations), files[np.argmin(durations)], files[np.argmax(durations)]
# Out:
# (0.6, 10.38, 'CM01_B2_CW51_M4.wav', 'M05_B1_UW41_M7.wav')

# %%
np.mean(durations)
# Out:
# 1.6166648590021693

# %%
np.histogram(durations, bins=[0,1,2,3,4,5,10,20], range=None)
# Out:
# (array([1826, 3963, 1083,  302,   93,  105,    4]),
#  array([ 0,  1,  2,  3,  4,  5, 10, 20]))

# %%
len(files)
# Out:
# 7376

# %%
dir = "preprocess"
files = []
durations = []
for p in os.listdir(dir):
    for f in os.listdir(f"{dir}/{p}"):
        durations.append(AudioSegment.from_file(f"{dir}/{p}/{f}").duration_seconds)
        files.append(f)
np.histogram(durations, bins=[0,1,2,3,4,5,10,20], range=None)
# Out:
# (array([59465, 67521,  5238,  1042,   291,   149,    13]),
#  array([ 0,  1,  2,  3,  4,  5, 10, 20]))

# %%
np.mean(durations), np.median(durations)
# Out:
# (1.1647109236533326, 1.05)

# %%
len(files)
# Out:
# 133719

# %%
dir = "preprocess-failed"
files = []
durations = []
for p in os.listdir(dir):
    for f in os.listdir(f"{dir}/{p}"):
        durations.append(AudioSegment.from_file(f"{dir}/{p}/{f}").duration_seconds)
        files.append(f)
np.histogram(durations, bins=[0,1,2,3,4,5,10,20], range=None)
# Out:
# (array([  0, 238,  70,  11,   1,   8,   3]),
#  array([ 0,  1,  2,  3,  4,  5, 10, 20]))

# %%
len(files)
# Out:
# 331

# %%
import shutil

target_dir = "preprocess"
source_dir = "preprocess-failed-2"
for p in os.listdir(source_dir):
    for f in os.listdir(f"{source_dir}/{p}"):
        print(f"Copying {source_dir}/{p}/{f} to {target_dir}/{p}/{f}")
        shutil.copy2(f"{source_dir}/{p}/{f}", f"{target_dir}/{p}")
# Out:
# Copying preprocess-failed-2/M12/M12_B1_UW21_M3.wav to preprocess/M12/M12_B1_UW21_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_UW73_M5.wav to preprocess/M12/M12_B1_UW73_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_UW96_M3.wav to preprocess/M12/M12_B2_UW96_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_CW57_M8.wav to preprocess/M12/M12_B1_CW57_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_CW94_M3.wav to preprocess/M12/M12_B1_CW94_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_UW100_M5.wav to preprocess/M12/M12_B1_UW100_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_C19_M5.wav to preprocess/M12/M12_B2_C19_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_UW3_M6.wav to preprocess/M12/M12_B1_UW3_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_LU_M7.wav to preprocess/M12/M12_B3_LU_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_CW49_M4.wav to preprocess/M12/M12_B1_CW49_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_UW44_M5.wav to preprocess/M12/M12_B3_UW44_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_UW89_M8.wav to preprocess/M12/M12_B3_UW89_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_CW29_M7.wav to preprocess/M12/M12_B2_CW29_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_UW81_M3.wav to preprocess/M12/M12_B1_UW81_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_UW31_M5.wav to preprocess/M12/M12_B2_UW31_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_UW78_M4.wav to preprocess/M12/M12_B1_UW78_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW44_M5.wav to preprocess/M12/M12_B1_UW44_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_UW11_M7.wav to preprocess/M12/M12_B3_UW11_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_CW36_M6.wav to preprocess/M12/M12_B2_CW36_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_UW9_M8.wav to preprocess/M12/M12_B1_UW9_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_UW40_M6.wav to preprocess/M12/M12_B2_UW40_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_UW59_M5.wav to preprocess/M12/M12_B1_UW59_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_UW42_M3.wav to preprocess/M12/M12_B1_UW42_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_D8_M6.wav to preprocess/M12/M12_B3_D8_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_LA_M5.wav to preprocess/M12/M12_B3_LA_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_CW74_M4.wav to preprocess/M12/M12_B1_CW74_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_LB_M7.wav to preprocess/M12/M12_B3_LB_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_UW8_M3.wav to preprocess/M12/M12_B1_UW8_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_UW25_M8.wav to preprocess/M12/M12_B3_UW25_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_UW38_M5.wav to preprocess/M12/M12_B2_UW38_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_CW48_M7.wav to preprocess/M12/M12_B2_CW48_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_UW40_M8.wav to preprocess/M12/M12_B3_UW40_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_CW74_M6.wav to preprocess/M12/M12_B2_CW74_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_LY_M4.wav to preprocess/M12/M12_B3_LY_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_C6_M5.wav to preprocess/M12/M12_B2_C6_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_C17_M6.wav to preprocess/M12/M12_B3_C17_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_CW56_M4.wav to preprocess/M12/M12_B2_CW56_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_UW31_M7.wav to preprocess/M12/M12_B3_UW31_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_UW30_M3.wav to preprocess/M12/M12_B2_UW30_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_UW5_M7.wav to preprocess/M12/M12_B3_UW5_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_CW3_M3.wav to preprocess/M12/M12_B2_CW3_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_UW13_M5.wav to preprocess/M12/M12_B2_UW13_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_UW51_M5.wav to preprocess/M12/M12_B3_UW51_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_UW68_M7.wav to preprocess/M12/M12_B1_UW68_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_CW33_M4.wav to preprocess/M12/M12_B3_CW33_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_LV_M8.wav to preprocess/M12/M12_B3_LV_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_UW15_M4.wav to preprocess/M12/M12_B1_UW15_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW23_M7.wav to preprocess/M12/M12_B1_UW23_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_CW32_M5.wav to preprocess/M12/M12_B2_CW32_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_UW55_M4.wav to preprocess/M12/M12_B3_UW55_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_CW64_M6.wav to preprocess/M12/M12_B3_CW64_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_UW20_M4.wav to preprocess/M12/M12_B1_UW20_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_CW73_M8.wav to preprocess/M12/M12_B2_CW73_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW64_M8.wav to preprocess/M12/M12_B3_UW64_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_CW75_M8.wav to preprocess/M12/M12_B2_CW75_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_C6_M3.wav to preprocess/M12/M12_B3_C6_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_UW23_M4.wav to preprocess/M12/M12_B1_UW23_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_UW25_M7.wav to preprocess/M12/M12_B3_UW25_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_CW77_M4.wav to preprocess/M12/M12_B1_CW77_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_UW76_M3.wav to preprocess/M12/M12_B3_UW76_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_CW39_M5.wav to preprocess/M12/M12_B3_CW39_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_C3_M4.wav to preprocess/M12/M12_B3_C3_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW42_M6.wav to preprocess/M12/M12_B1_UW42_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_UW57_M5.wav to preprocess/M12/M12_B1_UW57_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_UW38_M3.wav to preprocess/M12/M12_B2_UW38_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_C7_M7.wav to preprocess/M12/M12_B1_C7_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_UW29_M8.wav to preprocess/M12/M12_B3_UW29_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW12_M3.wav to preprocess/M12/M12_B3_CW12_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_C10_M6.wav to preprocess/M12/M12_B1_C10_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_UW75_M6.wav to preprocess/M12/M12_B3_UW75_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_UW60_M7.wav to preprocess/M12/M12_B1_UW60_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_CW94_M3.wav to preprocess/M12/M12_B3_CW94_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_UW45_M8.wav to preprocess/M12/M12_B3_UW45_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_CW44_M5.wav to preprocess/M12/M12_B1_CW44_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_D3_M4.wav to preprocess/M12/M12_B1_D3_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_UW21_M6.wav to preprocess/M12/M12_B3_UW21_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_C18_M7.wav to preprocess/M12/M12_B3_C18_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_UW76_M3.wav to preprocess/M12/M12_B2_UW76_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_UW86_M7.wav to preprocess/M12/M12_B2_UW86_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_LH_M4.wav to preprocess/M12/M12_B1_LH_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_CW58_M4.wav to preprocess/M12/M12_B3_CW58_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_LO_M4.wav to preprocess/M12/M12_B2_LO_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_CW37_M5.wav to preprocess/M12/M12_B3_CW37_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_CW13_M8.wav to preprocess/M12/M12_B1_CW13_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW9_M6.wav to preprocess/M12/M12_B3_UW9_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_UW60_M3.wav to preprocess/M12/M12_B3_UW60_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW44_M5.wav to preprocess/M12/M12_B2_CW44_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_CW56_M3.wav to preprocess/M12/M12_B2_CW56_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_UW21_M8.wav to preprocess/M12/M12_B3_UW21_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_UW73_M3.wav to preprocess/M12/M12_B2_UW73_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_CW73_M4.wav to preprocess/M12/M12_B3_CW73_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_CW13_M7.wav to preprocess/M12/M12_B1_CW13_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_UW35_M5.wav to preprocess/M12/M12_B1_UW35_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_C17_M7.wav to preprocess/M12/M12_B3_C17_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_LN_M8.wav to preprocess/M12/M12_B2_LN_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_UW36_M6.wav to preprocess/M12/M12_B2_UW36_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_D8_M7.wav to preprocess/M12/M12_B3_D8_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_C12_M5.wav to preprocess/M12/M12_B3_C12_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_LF_M7.wav to preprocess/M12/M12_B3_LF_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_UW84_M4.wav to preprocess/M12/M12_B2_UW84_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_LL_M4.wav to preprocess/M12/M12_B3_LL_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_CW43_M7.wav to preprocess/M12/M12_B1_CW43_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_CW8_M3.wav to preprocess/M12/M12_B3_CW8_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_LA_M3.wav to preprocess/M12/M12_B3_LA_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW72_M7.wav to preprocess/M12/M12_B2_CW72_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_UW77_M8.wav to preprocess/M12/M12_B3_UW77_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW7_M8.wav to preprocess/M12/M12_B3_CW7_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_LX_M6.wav to preprocess/M12/M12_B3_LX_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_CW25_M8.wav to preprocess/M12/M12_B3_CW25_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_LX_M7.wav to preprocess/M12/M12_B3_LX_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_UW29_M3.wav to preprocess/M12/M12_B3_UW29_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_UW100_M4.wav to preprocess/M12/M12_B1_UW100_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW83_M5.wav to preprocess/M12/M12_B1_UW83_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_CW47_M6.wav to preprocess/M12/M12_B1_CW47_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_CW34_M3.wav to preprocess/M12/M12_B3_CW34_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_CW47_M8.wav to preprocess/M12/M12_B3_CW47_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW39_M8.wav to preprocess/M12/M12_B3_CW39_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_UW75_M4.wav to preprocess/M12/M12_B1_UW75_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_LY_M6.wav to preprocess/M12/M12_B1_LY_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_CW50_M6.wav to preprocess/M12/M12_B3_CW50_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_LB_M6.wav to preprocess/M12/M12_B2_LB_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_CW55_M4.wav to preprocess/M12/M12_B1_CW55_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_UW16_M3.wav to preprocess/M12/M12_B3_UW16_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_CW26_M8.wav to preprocess/M12/M12_B1_CW26_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW31_M3.wav to preprocess/M12/M12_B3_CW31_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW71_M3.wav to preprocess/M12/M12_B2_CW71_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_UW96_M3.wav to preprocess/M12/M12_B3_UW96_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_CW35_M5.wav to preprocess/M12/M12_B1_CW35_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_UW20_M8.wav to preprocess/M12/M12_B2_UW20_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW72_M8.wav to preprocess/M12/M12_B3_CW72_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_CW38_M3.wav to preprocess/M12/M12_B1_CW38_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_D0_M7.wav to preprocess/M12/M12_B3_D0_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_CW86_M7.wav to preprocess/M12/M12_B1_CW86_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_CW77_M7.wav to preprocess/M12/M12_B1_CW77_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_UW50_M4.wav to preprocess/M12/M12_B2_UW50_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_UW86_M3.wav to preprocess/M12/M12_B2_UW86_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW53_M4.wav to preprocess/M12/M12_B2_CW53_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_UW75_M5.wav to preprocess/M12/M12_B2_UW75_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_LA_M6.wav to preprocess/M12/M12_B3_LA_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_LI_M7.wav to preprocess/M12/M12_B1_LI_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_UW2_M3.wav to preprocess/M12/M12_B1_UW2_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_C14_M8.wav to preprocess/M12/M12_B1_C14_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW90_M4.wav to preprocess/M12/M12_B3_UW90_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW44_M4.wav to preprocess/M12/M12_B1_UW44_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_CW14_M5.wav to preprocess/M12/M12_B2_CW14_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_LO_M6.wav to preprocess/M12/M12_B1_LO_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_C16_M4.wav to preprocess/M12/M12_B3_C16_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_CW78_M8.wav to preprocess/M12/M12_B1_CW78_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW90_M3.wav to preprocess/M12/M12_B3_UW90_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_UW58_M3.wav to preprocess/M12/M12_B2_UW58_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_CW26_M4.wav to preprocess/M12/M12_B1_CW26_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_C18_M8.wav to preprocess/M12/M12_B2_C18_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_CW35_M6.wav to preprocess/M12/M12_B1_CW35_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_CW15_M6.wav to preprocess/M12/M12_B3_CW15_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_CW78_M3.wav to preprocess/M12/M12_B1_CW78_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_UW56_M7.wav to preprocess/M12/M12_B1_UW56_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_CW21_M3.wav to preprocess/M12/M12_B1_CW21_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_UW62_M4.wav to preprocess/M12/M12_B2_UW62_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_CW14_M8.wav to preprocess/M12/M12_B2_CW14_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_CW26_M6.wav to preprocess/M12/M12_B2_CW26_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_LM_M3.wav to preprocess/M12/M12_B1_LM_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_LM_M4.wav to preprocess/M12/M12_B2_LM_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_UW50_M7.wav to preprocess/M12/M12_B2_UW50_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_CW32_M4.wav to preprocess/M12/M12_B2_CW32_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_UW20_M7.wav to preprocess/M12/M12_B2_UW20_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_UW18_M4.wav to preprocess/M12/M12_B1_UW18_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW15_M5.wav to preprocess/M12/M12_B1_UW15_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_UW77_M5.wav to preprocess/M12/M12_B3_UW77_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_UW72_M8.wav to preprocess/M12/M12_B2_UW72_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_UW49_M8.wav to preprocess/M12/M12_B1_UW49_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_CW18_M5.wav to preprocess/M12/M12_B2_CW18_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_CW89_M8.wav to preprocess/M12/M12_B3_CW89_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW67_M4.wav to preprocess/M12/M12_B3_UW67_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_CW29_M5.wav to preprocess/M12/M12_B2_CW29_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_C6_M5.wav to preprocess/M12/M12_B3_C6_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_LF_M6.wav to preprocess/M12/M12_B3_LF_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_UW33_M6.wav to preprocess/M12/M12_B3_UW33_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_CW11_M4.wav to preprocess/M12/M12_B2_CW11_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_CW11_M3.wav to preprocess/M12/M12_B2_CW11_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_UW9_M6.wav to preprocess/M12/M12_B1_UW9_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_LF_M8.wav to preprocess/M12/M12_B3_LF_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_CW74_M4.wav to preprocess/M12/M12_B2_CW74_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_CW81_M6.wav to preprocess/M12/M12_B2_CW81_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_UW69_M3.wav to preprocess/M12/M12_B3_UW69_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_CW35_M7.wav to preprocess/M12/M12_B1_CW35_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_UW8_M8.wav to preprocess/M12/M12_B1_UW8_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_UW96_M4.wav to preprocess/M12/M12_B2_UW96_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW44_M8.wav to preprocess/M12/M12_B1_UW44_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW58_M3.wav to preprocess/M12/M12_B3_CW58_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW41_M5.wav to preprocess/M12/M12_B2_CW41_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_UW3_M6.wav to preprocess/M12/M12_B3_UW3_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_CW81_M8.wav to preprocess/M12/M12_B1_CW81_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW10_M7.wav to preprocess/M12/M12_B3_CW10_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_C12_M4.wav to preprocess/M12/M12_B1_C12_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_LF_M5.wav to preprocess/M12/M12_B3_LF_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_CW94_M3.wav to preprocess/M12/M12_B2_CW94_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_LA_M4.wav to preprocess/M12/M12_B3_LA_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_C16_M8.wav to preprocess/M12/M12_B3_C16_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_LP_M8.wav to preprocess/M12/M12_B3_LP_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW21_M7.wav to preprocess/M12/M12_B3_UW21_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_CW71_M7.wav to preprocess/M12/M12_B3_CW71_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_CW39_M3.wav to preprocess/M12/M12_B1_CW39_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_UW6_M5.wav to preprocess/M12/M12_B1_UW6_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_CW34_M3.wav to preprocess/M12/M12_B1_CW34_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_UW49_M3.wav to preprocess/M12/M12_B1_UW49_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_D3_M7.wav to preprocess/M12/M12_B1_D3_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_CW39_M6.wav to preprocess/M12/M12_B3_CW39_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_UW34_M3.wav to preprocess/M12/M12_B3_UW34_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_CW71_M6.wav to preprocess/M12/M12_B3_CW71_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_UW60_M3.wav to preprocess/M12/M12_B1_UW60_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_UW18_M7.wav to preprocess/M12/M12_B2_UW18_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_LS_M6.wav to preprocess/M12/M12_B1_LS_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_CW70_M6.wav to preprocess/M12/M12_B3_CW70_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_UW81_M5.wav to preprocess/M12/M12_B1_UW81_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_LM_M5.wav to preprocess/M12/M12_B1_LM_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_UW13_M6.wav to preprocess/M12/M12_B1_UW13_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_C15_M8.wav to preprocess/M12/M12_B3_C15_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_LQ_M8.wav to preprocess/M12/M12_B3_LQ_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_LF_M3.wav to preprocess/M12/M12_B3_LF_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_C15_M8.wav to preprocess/M12/M12_B1_C15_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_UW21_M7.wav to preprocess/M12/M12_B1_UW21_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_CW99_M8.wav to preprocess/M12/M12_B3_CW99_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_D1_M5.wav to preprocess/M12/M12_B3_D1_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_UW48_M7.wav to preprocess/M12/M12_B2_UW48_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_D5_M8.wav to preprocess/M12/M12_B1_D5_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW2_M5.wav to preprocess/M12/M12_B3_CW2_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_UW38_M8.wav to preprocess/M12/M12_B3_UW38_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_CW70_M7.wav to preprocess/M12/M12_B1_CW70_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_UW2_M4.wav to preprocess/M12/M12_B2_UW2_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_CW99_M4.wav to preprocess/M12/M12_B3_CW99_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_CW17_M4.wav to preprocess/M12/M12_B2_CW17_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW35_M8.wav to preprocess/M12/M12_B1_UW35_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_CW26_M3.wav to preprocess/M12/M12_B2_CW26_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_UW50_M5.wav to preprocess/M12/M12_B2_UW50_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_CW37_M3.wav to preprocess/M12/M12_B3_CW37_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW50_M4.wav to preprocess/M12/M12_B2_CW50_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW57_M4.wav to preprocess/M12/M12_B1_UW57_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_CW83_M3.wav to preprocess/M12/M12_B3_CW83_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_UW18_M3.wav to preprocess/M12/M12_B1_UW18_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW1_M8.wav to preprocess/M12/M12_B2_CW1_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_LE_M8.wav to preprocess/M12/M12_B1_LE_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_LL_M7.wav to preprocess/M12/M12_B3_LL_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_UW84_M3.wav to preprocess/M12/M12_B2_UW84_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_CW31_M4.wav to preprocess/M12/M12_B3_CW31_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_UW67_M6.wav to preprocess/M12/M12_B3_UW67_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_CW32_M8.wav to preprocess/M12/M12_B2_CW32_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW90_M8.wav to preprocess/M12/M12_B3_UW90_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_UW33_M5.wav to preprocess/M12/M12_B1_UW33_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_UW4_M7.wav to preprocess/M12/M12_B3_UW4_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_UW18_M6.wav to preprocess/M12/M12_B1_UW18_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_CW76_M8.wav to preprocess/M12/M12_B3_CW76_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW10_M8.wav to preprocess/M12/M12_B3_UW10_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW7_M8.wav to preprocess/M12/M12_B3_UW7_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_CW51_M3.wav to preprocess/M12/M12_B1_CW51_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_CW51_M5.wav to preprocess/M12/M12_B1_CW51_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_UW3_M4.wav to preprocess/M12/M12_B1_UW3_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_CW41_M3.wav to preprocess/M12/M12_B1_CW41_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_UW5_M4.wav to preprocess/M12/M12_B3_UW5_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_CW37_M4.wav to preprocess/M12/M12_B2_CW37_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW46_M8.wav to preprocess/M12/M12_B1_UW46_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_LY_M8.wav to preprocess/M12/M12_B3_LY_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_C2_M3.wav to preprocess/M12/M12_B3_C2_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_LH_M3.wav to preprocess/M12/M12_B1_LH_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_UW98_M7.wav to preprocess/M12/M12_B1_UW98_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_UW39_M3.wav to preprocess/M12/M12_B3_UW39_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_UW90_M7.wav to preprocess/M12/M12_B3_UW90_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_UW13_M3.wav to preprocess/M12/M12_B2_UW13_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_UW91_M3.wav to preprocess/M12/M12_B2_UW91_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW38_M6.wav to preprocess/M12/M12_B2_CW38_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_CW81_M8.wav to preprocess/M12/M12_B2_CW81_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW16_M4.wav to preprocess/M12/M12_B3_UW16_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_UW16_M5.wav to preprocess/M12/M12_B3_UW16_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_UW76_M4.wav to preprocess/M12/M12_B2_UW76_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_CW76_M3.wav to preprocess/M12/M12_B3_CW76_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_CW71_M4.wav to preprocess/M12/M12_B3_CW71_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_LS_M5.wav to preprocess/M12/M12_B1_LS_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_CW71_M3.wav to preprocess/M12/M12_B3_CW71_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_UW73_M5.wav to preprocess/M12/M12_B2_UW73_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_CW87_M8.wav to preprocess/M12/M12_B3_CW87_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW70_M3.wav to preprocess/M12/M12_B3_CW70_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_UW5_M3.wav to preprocess/M12/M12_B2_UW5_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_CW10_M5.wav to preprocess/M12/M12_B3_CW10_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_CW3_M7.wav to preprocess/M12/M12_B3_CW3_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_UW62_M6.wav to preprocess/M12/M12_B3_UW62_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_C19_M4.wav to preprocess/M12/M12_B2_C19_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_UW22_M4.wav to preprocess/M12/M12_B2_UW22_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_UW34_M4.wav to preprocess/M12/M12_B2_UW34_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW6_M7.wav to preprocess/M12/M12_B1_UW6_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_C18_M6.wav to preprocess/M12/M12_B3_C18_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_LS_M3.wav to preprocess/M12/M12_B1_LS_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_UW21_M3.wav to preprocess/M12/M12_B3_UW21_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_C12_M7.wav to preprocess/M12/M12_B2_C12_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_CW18_M7.wav to preprocess/M12/M12_B2_CW18_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_UW50_M5.wav to preprocess/M12/M12_B3_UW50_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_CW1_M5.wav to preprocess/M12/M12_B1_CW1_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_UW42_M7.wav to preprocess/M12/M12_B2_UW42_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_UW91_M4.wav to preprocess/M12/M12_B2_UW91_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW81_M7.wav to preprocess/M12/M12_B1_UW81_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_CW26_M7.wav to preprocess/M12/M12_B1_CW26_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_UW94_M5.wav to preprocess/M12/M12_B2_UW94_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_C16_M6.wav to preprocess/M12/M12_B3_C16_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_LZ_M8.wav to preprocess/M12/M12_B1_LZ_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW76_M4.wav to preprocess/M12/M12_B3_CW76_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_UW31_M3.wav to preprocess/M12/M12_B2_UW31_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW19_M4.wav to preprocess/M12/M12_B2_CW19_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_CW34_M6.wav to preprocess/M12/M12_B1_CW34_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_CW65_M4.wav to preprocess/M12/M12_B1_CW65_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_CW59_M8.wav to preprocess/M12/M12_B3_CW59_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_CW57_M8.wav to preprocess/M12/M12_B2_CW57_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW13_M4.wav to preprocess/M12/M12_B3_CW13_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_CW38_M7.wav to preprocess/M12/M12_B3_CW38_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_CW84_M8.wav to preprocess/M12/M12_B1_CW84_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_UW68_M4.wav to preprocess/M12/M12_B2_UW68_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_CW89_M8.wav to preprocess/M12/M12_B1_CW89_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_UW62_M7.wav to preprocess/M12/M12_B1_UW62_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_CW1_M4.wav to preprocess/M12/M12_B2_CW1_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_UW59_M4.wav to preprocess/M12/M12_B2_UW59_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_UW77_M5.wav to preprocess/M12/M12_B2_UW77_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_UW36_M4.wav to preprocess/M12/M12_B3_UW36_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW73_M6.wav to preprocess/M12/M12_B1_UW73_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_UW62_M3.wav to preprocess/M12/M12_B3_UW62_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_CW93_M5.wav to preprocess/M12/M12_B1_CW93_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_CW89_M4.wav to preprocess/M12/M12_B2_CW89_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_D3_M3.wav to preprocess/M12/M12_B1_D3_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_UW3_M8.wav to preprocess/M12/M12_B1_UW3_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_UW13_M7.wav to preprocess/M12/M12_B2_UW13_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_UW11_M5.wav to preprocess/M12/M12_B3_UW11_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_CW38_M6.wav to preprocess/M12/M12_B3_CW38_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_UW70_M5.wav to preprocess/M12/M12_B1_UW70_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_UW69_M8.wav to preprocess/M12/M12_B3_UW69_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_CW90_M8.wav to preprocess/M12/M12_B2_CW90_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_LM_M3.wav to preprocess/M12/M12_B2_LM_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_C18_M5.wav to preprocess/M12/M12_B3_C18_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_CW55_M5.wav to preprocess/M12/M12_B2_CW55_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_CW65_M5.wav to preprocess/M12/M12_B1_CW65_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_D9_M4.wav to preprocess/M12/M12_B3_D9_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_CW48_M6.wav to preprocess/M12/M12_B2_CW48_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_UW38_M6.wav to preprocess/M12/M12_B2_UW38_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_UW61_M3.wav to preprocess/M12/M12_B1_UW61_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW70_M4.wav to preprocess/M12/M12_B2_CW70_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW62_M3.wav to preprocess/M12/M12_B1_UW62_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_CW70_M3.wav to preprocess/M12/M12_B1_CW70_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_CW80_M5.wav to preprocess/M12/M12_B3_CW80_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_UW61_M4.wav to preprocess/M12/M12_B1_UW61_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_UW12_M4.wav to preprocess/M12/M12_B3_UW12_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_CW94_M6.wav to preprocess/M12/M12_B1_CW94_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_CW12_M4.wav to preprocess/M12/M12_B3_CW12_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_CW38_M4.wav to preprocess/M12/M12_B2_CW38_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW35_M6.wav to preprocess/M12/M12_B1_UW35_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_CW89_M6.wav to preprocess/M12/M12_B3_CW89_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_CW16_M4.wav to preprocess/M12/M12_B3_CW16_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_UW75_M6.wav to preprocess/M12/M12_B2_UW75_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_UW52_M5.wav to preprocess/M12/M12_B2_UW52_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_UW59_M7.wav to preprocess/M12/M12_B3_UW59_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_UW56_M6.wav to preprocess/M12/M12_B3_UW56_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_UW3_M3.wav to preprocess/M12/M12_B1_UW3_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW40_M8.wav to preprocess/M12/M12_B2_CW40_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_UW54_M6.wav to preprocess/M12/M12_B1_UW54_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_UW76_M8.wav to preprocess/M12/M12_B1_UW76_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW50_M6.wav to preprocess/M12/M12_B3_UW50_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_LK_M4.wav to preprocess/M12/M12_B3_LK_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_UW96_M5.wav to preprocess/M12/M12_B3_UW96_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_CW96_M3.wav to preprocess/M12/M12_B2_CW96_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_C12_M4.wav to preprocess/M12/M12_B3_C12_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW47_M3.wav to preprocess/M12/M12_B1_UW47_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_UW47_M6.wav to preprocess/M12/M12_B1_UW47_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_CW71_M8.wav to preprocess/M12/M12_B3_CW71_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW92_M4.wav to preprocess/M12/M12_B3_UW92_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_D8_M4.wav to preprocess/M12/M12_B2_D8_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_CW47_M8.wav to preprocess/M12/M12_B1_CW47_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_UW98_M5.wav to preprocess/M12/M12_B1_UW98_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_UW86_M8.wav to preprocess/M12/M12_B2_UW86_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW76_M5.wav to preprocess/M12/M12_B3_UW76_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_UW22_M3.wav to preprocess/M12/M12_B2_UW22_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_LF_M8.wav to preprocess/M12/M12_B1_LF_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_LA_M8.wav to preprocess/M12/M12_B3_LA_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_CW18_M3.wav to preprocess/M12/M12_B2_CW18_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW78_M3.wav to preprocess/M12/M12_B2_CW78_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW18_M8.wav to preprocess/M12/M12_B2_CW18_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW82_M6.wav to preprocess/M12/M12_B3_CW82_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_CW14_M6.wav to preprocess/M12/M12_B1_CW14_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_CW82_M3.wav to preprocess/M12/M12_B1_CW82_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_UW44_M7.wav to preprocess/M12/M12_B3_UW44_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_UW97_M6.wav to preprocess/M12/M12_B1_UW97_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_CW6_M3.wav to preprocess/M12/M12_B2_CW6_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_CW1_M5.wav to preprocess/M12/M12_B3_CW1_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_CW6_M8.wav to preprocess/M12/M12_B2_CW6_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_CW64_M7.wav to preprocess/M12/M12_B1_CW64_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_CW22_M8.wav to preprocess/M12/M12_B3_CW22_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_CW94_M8.wav to preprocess/M12/M12_B2_CW94_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_UW40_M3.wav to preprocess/M12/M12_B2_UW40_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_UW45_M6.wav to preprocess/M12/M12_B1_UW45_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_CW42_M3.wav to preprocess/M12/M12_B1_CW42_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_CW61_M5.wav to preprocess/M12/M12_B1_CW61_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_CW48_M5.wav to preprocess/M12/M12_B2_CW48_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_LF_M7.wav to preprocess/M12/M12_B2_LF_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_UW41_M3.wav to preprocess/M12/M12_B3_UW41_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_D1_M3.wav to preprocess/M12/M12_B3_D1_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_UW56_M7.wav to preprocess/M12/M12_B3_UW56_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_UW20_M3.wav to preprocess/M12/M12_B1_UW20_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_CW35_M3.wav to preprocess/M12/M12_B3_CW35_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_CW6_M7.wav to preprocess/M12/M12_B3_CW6_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_UW66_M8.wav to preprocess/M12/M12_B2_UW66_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW27_M6.wav to preprocess/M12/M12_B3_UW27_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_CW57_M6.wav to preprocess/M12/M12_B1_CW57_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_UW79_M3.wav to preprocess/M12/M12_B2_UW79_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_UW98_M5.wav to preprocess/M12/M12_B2_UW98_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_CW14_M3.wav to preprocess/M12/M12_B2_CW14_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_UW33_M3.wav to preprocess/M12/M12_B3_UW33_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW6_M6.wav to preprocess/M12/M12_B2_CW6_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_UW80_M6.wav to preprocess/M12/M12_B2_UW80_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_UW24_M4.wav to preprocess/M12/M12_B3_UW24_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_LK_M4.wav to preprocess/M12/M12_B1_LK_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_CW48_M5.wav to preprocess/M12/M12_B3_CW48_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_UW60_M6.wav to preprocess/M12/M12_B1_UW60_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_CW54_M8.wav to preprocess/M12/M12_B1_CW54_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_CW34_M4.wav to preprocess/M12/M12_B1_CW34_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_D8_M3.wav to preprocess/M12/M12_B2_D8_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW6_M7.wav to preprocess/M12/M12_B2_CW6_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_LY_M3.wav to preprocess/M12/M12_B3_LY_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_UW95_M7.wav to preprocess/M12/M12_B2_UW95_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_CW49_M3.wav to preprocess/M12/M12_B3_CW49_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW62_M6.wav to preprocess/M12/M12_B2_CW62_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_CW47_M3.wav to preprocess/M12/M12_B1_CW47_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_UW92_M7.wav to preprocess/M12/M12_B3_UW92_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_UW82_M8.wav to preprocess/M12/M12_B1_UW82_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_UW27_M7.wav to preprocess/M12/M12_B1_UW27_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_C5_M8.wav to preprocess/M12/M12_B3_C5_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW60_M8.wav to preprocess/M12/M12_B3_UW60_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_CW16_M8.wav to preprocess/M12/M12_B2_CW16_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_CW32_M3.wav to preprocess/M12/M12_B2_CW32_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_LE_M7.wav to preprocess/M12/M12_B2_LE_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_UW54_M7.wav to preprocess/M12/M12_B1_UW54_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_UW13_M5.wav to preprocess/M12/M12_B1_UW13_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_UW64_M5.wav to preprocess/M12/M12_B3_UW64_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_UW96_M8.wav to preprocess/M12/M12_B2_UW96_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_CW64_M4.wav to preprocess/M12/M12_B1_CW64_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_CW10_M4.wav to preprocess/M12/M12_B3_CW10_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_UW34_M8.wav to preprocess/M12/M12_B2_UW34_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW6_M8.wav to preprocess/M12/M12_B3_CW6_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_CW12_M6.wav to preprocess/M12/M12_B2_CW12_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_LU_M5.wav to preprocess/M12/M12_B2_LU_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_UW3_M7.wav to preprocess/M12/M12_B3_UW3_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_UW57_M6.wav to preprocess/M12/M12_B3_UW57_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_UW62_M5.wav to preprocess/M12/M12_B2_UW62_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_CW81_M7.wav to preprocess/M12/M12_B2_CW81_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_CW8_M7.wav to preprocess/M12/M12_B1_CW8_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_UW79_M5.wav to preprocess/M12/M12_B1_UW79_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_CW37_M8.wav to preprocess/M12/M12_B2_CW37_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW34_M5.wav to preprocess/M12/M12_B3_CW34_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_LK_M5.wav to preprocess/M12/M12_B3_LK_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_UW18_M5.wav to preprocess/M12/M12_B1_UW18_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_CW90_M7.wav to preprocess/M12/M12_B2_CW90_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_UW55_M6.wav to preprocess/M12/M12_B3_UW55_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_LW_M6.wav to preprocess/M12/M12_B1_LW_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_UW73_M4.wav to preprocess/M12/M12_B2_UW73_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_CW74_M7.wav to preprocess/M12/M12_B1_CW74_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_LK_M6.wav to preprocess/M12/M12_B3_LK_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_CW16_M7.wav to preprocess/M12/M12_B3_CW16_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_UW96_M6.wav to preprocess/M12/M12_B3_UW96_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_UW92_M8.wav to preprocess/M12/M12_B1_UW92_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_UW84_M8.wav to preprocess/M12/M12_B2_UW84_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_LK_M7.wav to preprocess/M12/M12_B1_LK_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_UW56_M8.wav to preprocess/M12/M12_B1_UW56_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW12_M6.wav to preprocess/M12/M12_B3_CW12_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_CW37_M3.wav to preprocess/M12/M12_B2_CW37_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_CW3_M5.wav to preprocess/M12/M12_B3_CW3_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_UW13_M8.wav to preprocess/M12/M12_B2_UW13_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW37_M6.wav to preprocess/M12/M12_B3_CW37_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_UW96_M4.wav to preprocess/M12/M12_B3_UW96_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_LE_M6.wav to preprocess/M12/M12_B1_LE_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_CW13_M8.wav to preprocess/M12/M12_B3_CW13_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_UW62_M7.wav to preprocess/M12/M12_B2_UW62_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_UW70_M4.wav to preprocess/M12/M12_B1_UW70_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_UW38_M8.wav to preprocess/M12/M12_B2_UW38_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW62_M7.wav to preprocess/M12/M12_B3_UW62_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_C10_M3.wav to preprocess/M12/M12_B1_C10_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_CW74_M6.wav to preprocess/M12/M12_B1_CW74_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_CW83_M4.wav to preprocess/M12/M12_B3_CW83_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_C12_M8.wav to preprocess/M12/M12_B2_C12_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_D2_M8.wav to preprocess/M12/M12_B2_D2_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_UW40_M4.wav to preprocess/M12/M12_B2_UW40_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_CW14_M7.wav to preprocess/M12/M12_B2_CW14_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_CW15_M4.wav to preprocess/M12/M12_B1_CW15_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW92_M3.wav to preprocess/M12/M12_B1_UW92_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_UW57_M5.wav to preprocess/M12/M12_B3_UW57_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_UW83_M3.wav to preprocess/M12/M12_B1_UW83_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_CW41_M4.wav to preprocess/M12/M12_B1_CW41_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW54_M5.wav to preprocess/M12/M12_B1_UW54_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_CW49_M8.wav to preprocess/M12/M12_B2_CW49_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_CW69_M3.wav to preprocess/M12/M12_B1_CW69_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW71_M6.wav to preprocess/M12/M12_B2_CW71_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_UW13_M6.wav to preprocess/M12/M12_B2_UW13_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_C16_M3.wav to preprocess/M12/M12_B3_C16_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_UW45_M3.wav to preprocess/M12/M12_B1_UW45_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_CW33_M5.wav to preprocess/M12/M12_B3_CW33_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_UW74_M5.wav to preprocess/M12/M12_B2_UW74_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_UW96_M8.wav to preprocess/M12/M12_B1_UW96_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_CW29_M6.wav to preprocess/M12/M12_B2_CW29_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_UW8_M8.wav to preprocess/M12/M12_B3_UW8_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW24_M3.wav to preprocess/M12/M12_B3_UW24_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_UW92_M3.wav to preprocess/M12/M12_B3_UW92_M3.wav
# Copying preprocess-failed-2/M12/M12_B2_CW73_M5.wav to preprocess/M12/M12_B2_CW73_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_C2_M4.wav to preprocess/M12/M12_B3_C2_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_UW36_M6.wav to preprocess/M12/M12_B3_UW36_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_UW58_M5.wav to preprocess/M12/M12_B2_UW58_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_UW84_M5.wav to preprocess/M12/M12_B2_UW84_M5.wav
# Copying preprocess-failed-2/M12/M12_B1_UW8_M7.wav to preprocess/M12/M12_B1_UW8_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_UW61_M8.wav to preprocess/M12/M12_B2_UW61_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_LO_M8.wav to preprocess/M12/M12_B2_LO_M8.wav
# Copying preprocess-failed-2/M12/M12_B2_UW80_M5.wav to preprocess/M12/M12_B2_UW80_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_C1_M8.wav to preprocess/M12/M12_B3_C1_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW8_M8.wav to preprocess/M12/M12_B3_CW8_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW36_M8.wav to preprocess/M12/M12_B3_CW36_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_CW48_M4.wav to preprocess/M12/M12_B3_CW48_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_C6_M4.wav to preprocess/M12/M12_B2_C6_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_UW32_M5.wav to preprocess/M12/M12_B3_UW32_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_CW57_M4.wav to preprocess/M12/M12_B3_CW57_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_CW93_M4.wav to preprocess/M12/M12_B1_CW93_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_UW36_M3.wav to preprocess/M12/M12_B3_UW36_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_CW66_M7.wav to preprocess/M12/M12_B1_CW66_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_CW54_M3.wav to preprocess/M12/M12_B1_CW54_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_UW69_M5.wav to preprocess/M12/M12_B3_UW69_M5.wav
# Copying preprocess-failed-2/M12/M12_B2_CW56_M6.wav to preprocess/M12/M12_B2_CW56_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_C12_M6.wav to preprocess/M12/M12_B1_C12_M6.wav
# Copying preprocess-failed-2/M12/M12_B2_CW34_M6.wav to preprocess/M12/M12_B2_CW34_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_CW35_M4.wav to preprocess/M12/M12_B1_CW35_M4.wav
# Copying preprocess-failed-2/M12/M12_B2_UW45_M4.wav to preprocess/M12/M12_B2_UW45_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_CW93_M3.wav to preprocess/M12/M12_B1_CW93_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_CW76_M7.wav to preprocess/M12/M12_B3_CW76_M7.wav
# Copying preprocess-failed-2/M12/M12_B3_CW6_M6.wav to preprocess/M12/M12_B3_CW6_M6.wav
# Copying preprocess-failed-2/M12/M12_B1_LM_M4.wav to preprocess/M12/M12_B1_LM_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW79_M4.wav to preprocess/M12/M12_B1_UW79_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_CW69_M7.wav to preprocess/M12/M12_B3_CW69_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_UW51_M7.wav to preprocess/M12/M12_B2_UW51_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_CW14_M7.wav to preprocess/M12/M12_B1_CW14_M7.wav
# Copying preprocess-failed-2/M12/M12_B1_CW42_M6.wav to preprocess/M12/M12_B1_CW42_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_CW82_M4.wav to preprocess/M12/M12_B3_CW82_M4.wav
# Copying preprocess-failed-2/M12/M12_B1_UW13_M8.wav to preprocess/M12/M12_B1_UW13_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_D1_M7.wav to preprocess/M12/M12_B3_D1_M7.wav
# Copying preprocess-failed-2/M12/M12_B2_LF_M3.wav to preprocess/M12/M12_B2_LF_M3.wav
# Copying preprocess-failed-2/M12/M12_B3_CW31_M6.wav to preprocess/M12/M12_B3_CW31_M6.wav
# Copying preprocess-failed-2/M12/M12_B3_CW95_M8.wav to preprocess/M12/M12_B3_CW95_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW55_M8.wav to preprocess/M12/M12_B3_UW55_M8.wav
# Copying preprocess-failed-2/M12/M12_B1_CW73_M4.wav to preprocess/M12/M12_B1_CW73_M4.wav
# Copying preprocess-failed-2/M12/M12_B3_LS_M8.wav to preprocess/M12/M12_B3_LS_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_UW24_M5.wav to preprocess/M12/M12_B3_UW24_M5.wav
# Copying preprocess-failed-2/M12/M12_B3_UW78_M8.wav to preprocess/M12/M12_B3_UW78_M8.wav
# Copying preprocess-failed-2/M12/M12_B3_LK_M3.wav to preprocess/M12/M12_B3_LK_M3.wav
# Copying preprocess-failed-2/M12/M12_B1_UW79_M8.wav to preprocess/M12/M12_B1_UW79_M8.wav
# ...
# Copying preprocess-failed-2/M05/M05_B1_UW41_M8.wav to preprocess/M05/M05_B1_UW41_M8.wav
# Copying preprocess-failed-2/M05/M05_B1_LK_M3.wav to preprocess/M05/M05_B1_LK_M3.wav
# Copying preprocess-failed-2/M05/M05_B1_CW16_M7.wav to preprocess/M05/M05_B1_CW16_M7.wav
# Copying preprocess-failed-2/M05/M05_B1_UW73_M2.wav to preprocess/M05/M05_B1_UW73_M2.wav
# Copying preprocess-failed-2/M05/M05_B3_UW68_M8.wav to preprocess/M05/M05_B3_UW68_M8.wav
# Copying preprocess-failed-2/M05/M05_B2_UW64_M3.wav to preprocess/M05/M05_B2_UW64_M3.wav
# Copying preprocess-failed-2/M05/M05_B1_UW55_M8.wav to preprocess/M05/M05_B1_UW55_M8.wav
# Copying preprocess-failed-2/M05/M05_B2_UW45_M8.wav to preprocess/M05/M05_B2_UW45_M8.wav
# Copying preprocess-failed-2/M05/M05_B2_UW19_M4.wav to preprocess/M05/M05_B2_UW19_M4.wav
# Copying preprocess-failed-2/M05/M05_B1_UW51_M8.wav to preprocess/M05/M05_B1_UW51_M8.wav
# Copying preprocess-failed-2/M05/M05_B2_CW62_M2.wav to preprocess/M05/M05_B2_CW62_M2.wav
# Copying preprocess-failed-2/M05/M05_B2_UW30_M6.wav to preprocess/M05/M05_B2_UW30_M6.wav
# Copying preprocess-failed-2/M05/M05_B1_UW47_M2.wav to preprocess/M05/M05_B1_UW47_M2.wav
# Copying preprocess-failed-2/M05/M05_B2_UW45_M3.wav to preprocess/M05/M05_B2_UW45_M3.wav
# Copying preprocess-failed-2/M05/M05_B2_CW21_M6.wav to preprocess/M05/M05_B2_CW21_M6.wav
# Copying preprocess-failed-2/M05/M05_B1_UW48_M8.wav to preprocess/M05/M05_B1_UW48_M8.wav
# Copying preprocess-failed-2/M05/M05_B3_CW40_M5.wav to preprocess/M05/M05_B3_CW40_M5.wav
# Copying preprocess-failed-2/M05/M05_B3_CW20_M3.wav to preprocess/M05/M05_B3_CW20_M3.wav
# Copying preprocess-failed-2/M05/M05_B1_UW88_M8.wav to preprocess/M05/M05_B1_UW88_M8.wav
# Copying preprocess-failed-2/M05/M05_B1_UW50_M2.wav to preprocess/M05/M05_B1_UW50_M2.wav
# Copying preprocess-failed-2/M05/M05_B1_UW83_M4.wav to preprocess/M05/M05_B1_UW83_M4.wav
# Copying preprocess-failed-2/M05/M05_B1_UW3_M6.wav to preprocess/M05/M05_B1_UW3_M6.wav
# Copying preprocess-failed-2/M05/M05_B1_UW47_M8.wav to preprocess/M05/M05_B1_UW47_M8.wav
# Copying preprocess-failed-2/M05/M05_B3_UW45_M3.wav to preprocess/M05/M05_B3_UW45_M3.wav
# Copying preprocess-failed-2/M05/M05_B3_CW99_M7.wav to preprocess/M05/M05_B3_CW99_M7.wav
# Copying preprocess-failed-2/M05/M05_B1_UW75_M5.wav to preprocess/M05/M05_B1_UW75_M5.wav
# Copying preprocess-failed-2/M05/M05_B3_UW51_M3.wav to preprocess/M05/M05_B3_UW51_M3.wav
# Copying preprocess-failed-2/M05/M05_B1_C11_M4.wav to preprocess/M05/M05_B1_C11_M4.wav
# Copying preprocess-failed-2/M05/M05_B3_LE_M6.wav to preprocess/M05/M05_B3_LE_M6.wav
# Copying preprocess-failed-2/M05/M05_B1_D3_M8.wav to preprocess/M05/M05_B1_D3_M8.wav
# Copying preprocess-failed-2/M05/M05_B1_CW2_M4.wav to preprocess/M05/M05_B1_CW2_M4.wav
# Copying preprocess-failed-2/M05/M05_B3_UW1_M4.wav to preprocess/M05/M05_B3_UW1_M4.wav
# Copying preprocess-failed-2/M05/M05_B3_UW33_M2.wav to preprocess/M05/M05_B3_UW33_M2.wav
# Copying preprocess-failed-2/M05/M05_B1_UW73_M8.wav to preprocess/M05/M05_B1_UW73_M8.wav
# Copying preprocess-failed-2/M05/M05_B2_UW18_M8.wav to preprocess/M05/M05_B2_UW18_M8.wav
# Copying preprocess-failed-2/M05/M05_B1_CW16_M6.wav to preprocess/M05/M05_B1_CW16_M6.wav
# Copying preprocess-failed-2/M05/M05_B1_UW50_M3.wav to preprocess/M05/M05_B1_UW50_M3.wav
# Copying preprocess-failed-2/M05/M05_B3_UW59_M2.wav to preprocess/M05/M05_B3_UW59_M2.wav
# Copying preprocess-failed-2/M05/M05_B3_UW34_M7.wav to preprocess/M05/M05_B3_UW34_M7.wav
# Copying preprocess-failed-2/M05/M05_B1_UW75_M3.wav to preprocess/M05/M05_B1_UW75_M3.wav
# Copying preprocess-failed-2/M05/M05_B2_CW51_M7.wav to preprocess/M05/M05_B2_CW51_M7.wav
# Copying preprocess-failed-2/M05/M05_B3_D0_M4.wav to preprocess/M05/M05_B3_D0_M4.wav
# Copying preprocess-failed-2/M05/M05_B2_UW31_M2.wav to preprocess/M05/M05_B2_UW31_M2.wav
# Copying preprocess-failed-2/M05/M05_B1_CW3_M6.wav to preprocess/M05/M05_B1_CW3_M6.wav
# Copying preprocess-failed-2/M05/M05_B1_CW16_M8.wav to preprocess/M05/M05_B1_CW16_M8.wav
# Copying preprocess-failed-2/M05/M05_B2_CW21_M7.wav to preprocess/M05/M05_B2_CW21_M7.wav
# Copying preprocess-failed-2/M05/M05_B3_CW4_M2.wav to preprocess/M05/M05_B3_CW4_M2.wav
# Copying preprocess-failed-2/M05/M05_B2_UW36_M5.wav to preprocess/M05/M05_B2_UW36_M5.wav
# Copying preprocess-failed-2/M05/M05_B1_LE_M5.wav to preprocess/M05/M05_B1_LE_M5.wav
# Copying preprocess-failed-2/M05/M05_B1_D2_M7.wav to preprocess/M05/M05_B1_D2_M7.wav
# Copying preprocess-failed-2/M05/M05_B3_UW59_M5.wav to preprocess/M05/M05_B3_UW59_M5.wav
# Copying preprocess-failed-2/M05/M05_B2_CW3_M8.wav to preprocess/M05/M05_B2_CW3_M8.wav
# Copying preprocess-failed-2/M05/M05_B2_CW58_M8.wav to preprocess/M05/M05_B2_CW58_M8.wav
# Copying preprocess-failed-2/M05/M05_B2_UW19_M3.wav to preprocess/M05/M05_B2_UW19_M3.wav
# Copying preprocess-failed-2/M05/M05_B2_UW19_M8.wav to preprocess/M05/M05_B2_UW19_M8.wav
# Copying preprocess-failed-2/M05/M05_B3_LE_M4.wav to preprocess/M05/M05_B3_LE_M4.wav
# Copying preprocess-failed-2/M05/M05_B1_CW28_M5.wav to preprocess/M05/M05_B1_CW28_M5.wav
# Copying preprocess-failed-2/M05/M05_B1_CW16_M3.wav to preprocess/M05/M05_B1_CW16_M3.wav
# Copying preprocess-failed-2/M05/M05_B2_UW54_M4.wav to preprocess/M05/M05_B2_UW54_M4.wav
# Copying preprocess-failed-2/M05/M05_B3_LB_M8.wav to preprocess/M05/M05_B3_LB_M8.wav
# Copying preprocess-failed-2/M05/M05_B3_UW72_M6.wav to preprocess/M05/M05_B3_UW72_M6.wav
# Copying preprocess-failed-2/M05/M05_B1_UW23_M8.wav to preprocess/M05/M05_B1_UW23_M8.wav
# Copying preprocess-failed-2/M05/M05_B1_UW81_M3.wav to preprocess/M05/M05_B1_UW81_M3.wav
# Copying preprocess-failed-2/M05/M05_B1_UW34_M4.wav to preprocess/M05/M05_B1_UW34_M4.wav
# Copying preprocess-failed-2/M05/M05_B3_UW45_M8.wav to preprocess/M05/M05_B3_UW45_M8.wav
# Copying preprocess-failed-2/M05/M05_B2_UW63_M4.wav to preprocess/M05/M05_B2_UW63_M4.wav
# Copying preprocess-failed-2/M05/M05_B2_UW57_M5.wav to preprocess/M05/M05_B2_UW57_M5.wav
# Copying preprocess-failed-2/M05/M05_B2_LK_M4.wav to preprocess/M05/M05_B2_LK_M4.wav
# Copying preprocess-failed-2/M05/M05_B3_UW18_M8.wav to preprocess/M05/M05_B3_UW18_M8.wav
# Copying preprocess-failed-2/M05/M05_B2_UW44_M8.wav to preprocess/M05/M05_B2_UW44_M8.wav
# Copying preprocess-failed-2/M05/M05_B2_CW51_M8.wav to preprocess/M05/M05_B2_CW51_M8.wav
# Copying preprocess-failed-2/M05/M05_B3_UW18_M5.wav to preprocess/M05/M05_B3_UW18_M5.wav
# Copying preprocess-failed-2/M05/M05_B1_CW14_M2.wav to preprocess/M05/M05_B1_CW14_M2.wav
# Copying preprocess-failed-2/M05/M05_B3_CW4_M4.wav to preprocess/M05/M05_B3_CW4_M4.wav
# Copying preprocess-failed-2/M05/M05_B1_CW51_M8.wav to preprocess/M05/M05_B1_CW51_M8.wav
# Copying preprocess-failed-2/M05/M05_B3_CW40_M8.wav to preprocess/M05/M05_B3_CW40_M8.wav
# Copying preprocess-failed-2/M05/M05_B1_UW7_M2.wav to preprocess/M05/M05_B1_UW7_M2.wav
# Copying preprocess-failed-2/M05/M05_B1_UW72_M3.wav to preprocess/M05/M05_B1_UW72_M3.wav
# Copying preprocess-failed-2/M05/M05_B3_UW51_M7.wav to preprocess/M05/M05_B3_UW51_M7.wav
# Copying preprocess-failed-2/M05/M05_B3_CW20_M7.wav to preprocess/M05/M05_B3_CW20_M7.wav
# Copying preprocess-failed-2/M05/M05_B1_LW_M4.wav to preprocess/M05/M05_B1_LW_M4.wav
# Copying preprocess-failed-2/M05/M05_B1_UW75_M2.wav to preprocess/M05/M05_B1_UW75_M2.wav
# Copying preprocess-failed-2/M05/M05_B3_CW20_M4.wav to preprocess/M05/M05_B3_CW20_M4.wav
# Copying preprocess-failed-2/M05/M05_B2_CW6_M8.wav to preprocess/M05/M05_B2_CW6_M8.wav
# Copying preprocess-failed-2/M05/M05_B2_UW57_M3.wav to preprocess/M05/M05_B2_UW57_M3.wav
# Copying preprocess-failed-2/M05/M05_B3_C13_M2.wav to preprocess/M05/M05_B3_C13_M2.wav
# Copying preprocess-failed-2/M05/M05_B3_CW87_M8.wav to preprocess/M05/M05_B3_CW87_M8.wav
# Copying preprocess-failed-2/M05/M05_B1_CW54_M6.wav to preprocess/M05/M05_B1_CW54_M6.wav
# Copying preprocess-failed-2/M05/M05_B3_UW45_M5.wav to preprocess/M05/M05_B3_UW45_M5.wav
# Copying preprocess-failed-2/M05/M05_B1_UW45_M8.wav to preprocess/M05/M05_B1_UW45_M8.wav
# Copying preprocess-failed-2/M05/M05_B1_UW48_M5.wav to preprocess/M05/M05_B1_UW48_M5.wav
# Copying preprocess-failed-2/M05/M05_B1_UW75_M4.wav to preprocess/M05/M05_B1_UW75_M4.wav
# Copying preprocess-failed-2/M05/M05_B3_UW38_M8.wav to preprocess/M05/M05_B3_UW38_M8.wav
# Copying preprocess-failed-2/M05/M05_B2_LK_M6.wav to preprocess/M05/M05_B2_LK_M6.wav
# Copying preprocess-failed-2/M05/M05_B1_UW73_M3.wav to preprocess/M05/M05_B1_UW73_M3.wav
# Copying preprocess-failed-2/M05/M05_B1_CW38_M4.wav to preprocess/M05/M05_B1_CW38_M4.wav
# Copying preprocess-failed-2/M05/M05_B2_CW6_M5.wav to preprocess/M05/M05_B2_CW6_M5.wav
# Copying preprocess-failed-2/M05/M05_B1_UW12_M5.wav to preprocess/M05/M05_B1_UW12_M5.wav
# Copying preprocess-failed-2/M05/M05_B1_C11_M5.wav to preprocess/M05/M05_B1_C11_M5.wav
# Copying preprocess-failed-2/M05/M05_B1_UW4_M4.wav to preprocess/M05/M05_B1_UW4_M4.wav
# Copying preprocess-failed-2/M05/M05_B2_LK_M8.wav to preprocess/M05/M05_B2_LK_M8.wav
# Copying preprocess-failed-2/M05/M05_B3_CW49_M4.wav to preprocess/M05/M05_B3_CW49_M4.wav
# Copying preprocess-failed-2/M05/M05_B3_UW45_M7.wav to preprocess/M05/M05_B3_UW45_M7.wav
# Copying preprocess-failed-2/M05/M05_B1_UW70_M4.wav to preprocess/M05/M05_B1_UW70_M4.wav
# Copying preprocess-failed-2/M05/M05_B2_UW30_M5.wav to preprocess/M05/M05_B2_UW30_M5.wav
# Copying preprocess-failed-2/M05/M05_B2_UW18_M7.wav to preprocess/M05/M05_B2_UW18_M7.wav
# Copying preprocess-failed-2/M05/M05_B2_CW21_M8.wav to preprocess/M05/M05_B2_CW21_M8.wav
# Copying preprocess-failed-2/M05/M05_B1_UW4_M7.wav to preprocess/M05/M05_B1_UW4_M7.wav
# Copying preprocess-failed-2/M05/M05_B1_UW54_M8.wav to preprocess/M05/M05_B1_UW54_M8.wav
# Copying preprocess-failed-2/M05/M05_B2_CW2_M4.wav to preprocess/M05/M05_B2_CW2_M4.wav
# Copying preprocess-failed-2/M05/M05_B1_UW12_M6.wav to preprocess/M05/M05_B1_UW12_M6.wav
# Copying preprocess-failed-2/M05/M05_B1_UW34_M6.wav to preprocess/M05/M05_B1_UW34_M6.wav
# Copying preprocess-failed-2/M05/M05_B3_CW20_M6.wav to preprocess/M05/M05_B3_CW20_M6.wav
# Copying preprocess-failed-2/M05/M05_B3_UW30_M5.wav to preprocess/M05/M05_B3_UW30_M5.wav
# Copying preprocess-failed-2/M05/M05_B3_LI_M4.wav to preprocess/M05/M05_B3_LI_M4.wav
# Copying preprocess-failed-2/M05/M05_B1_UW12_M3.wav to preprocess/M05/M05_B1_UW12_M3.wav
# Copying preprocess-failed-2/M05/M05_B3_UW72_M3.wav to preprocess/M05/M05_B3_UW72_M3.wav
# Copying preprocess-failed-2/M05/M05_B3_UW68_M3.wav to preprocess/M05/M05_B3_UW68_M3.wav
# Copying preprocess-failed-2/M05/M05_B3_CW20_M5.wav to preprocess/M05/M05_B3_CW20_M5.wav
# Copying preprocess-failed-2/M05/M05_B3_CW54_M7.wav to preprocess/M05/M05_B3_CW54_M7.wav
# Copying preprocess-failed-2/M05/M05_B1_CW49_M5.wav to preprocess/M05/M05_B1_CW49_M5.wav
# Copying preprocess-failed-2/M05/M05_B3_LK_M3.wav to preprocess/M05/M05_B3_LK_M3.wav
# Copying preprocess-failed-2/M05/M05_B3_CW10_M2.wav to preprocess/M05/M05_B3_CW10_M2.wav
# Copying preprocess-failed-2/M05/M05_B1_UW28_M2.wav to preprocess/M05/M05_B1_UW28_M2.wav
# Copying preprocess-failed-2/M05/M05_B3_CW33_M4.wav to preprocess/M05/M05_B3_CW33_M4.wav
# Copying preprocess-failed-2/M05/M05_B1_C11_M3.wav to preprocess/M05/M05_B1_C11_M3.wav
# Copying preprocess-failed-2/M05/M05_B2_CW92_M2.wav to preprocess/M05/M05_B2_CW92_M2.wav
# Copying preprocess-failed-2/M05/M05_B3_UW30_M8.wav to preprocess/M05/M05_B3_UW30_M8.wav
# Copying preprocess-failed-2/M05/M05_B2_UW81_M2.wav to preprocess/M05/M05_B2_UW81_M2.wav
# Copying preprocess-failed-2/M05/M05_B2_UW1_M8.wav to preprocess/M05/M05_B2_UW1_M8.wav
# Copying preprocess-failed-2/M05/M05_B1_UW89_M2.wav to preprocess/M05/M05_B1_UW89_M2.wav
# Copying preprocess-failed-2/M05/M05_B3_UW34_M5.wav to preprocess/M05/M05_B3_UW34_M5.wav
# Copying preprocess-failed-2/M05/M05_B1_UW73_M7.wav to preprocess/M05/M05_B1_UW73_M7.wav
# Copying preprocess-failed-2/M05/M05_B1_UW73_M6.wav to preprocess/M05/M05_B1_UW73_M6.wav
# Copying preprocess-failed-2/M05/M05_B3_UW68_M7.wav to preprocess/M05/M05_B3_UW68_M7.wav
# Copying preprocess-failed-2/M05/M05_B3_UW34_M8.wav to preprocess/M05/M05_B3_UW34_M8.wav
# Copying preprocess-failed-2/M05/M05_B1_D8_M8.wav to preprocess/M05/M05_B1_D8_M8.wav
# Copying preprocess-failed-2/M05/M05_B1_CW14_M4.wav to preprocess/M05/M05_B1_CW14_M4.wav
# Copying preprocess-failed-2/M05/M05_B3_LI_M2.wav to preprocess/M05/M05_B3_LI_M2.wav
# Copying preprocess-failed-2/M05/M05_B1_UW23_M5.wav to preprocess/M05/M05_B1_UW23_M5.wav
# Copying preprocess-failed-2/M05/M05_B1_LE_M2.wav to preprocess/M05/M05_B1_LE_M2.wav
# Copying preprocess-failed-2/M05/M05_B1_CW3_M7.wav to preprocess/M05/M05_B1_CW3_M7.wav
# Copying preprocess-failed-2/M05/M05_B1_CW30_M2.wav to preprocess/M05/M05_B1_CW30_M2.wav
# Copying preprocess-failed-2/M05/M05_B1_UW12_M2.wav to preprocess/M05/M05_B1_UW12_M2.wav
# Copying preprocess-failed-2/M05/M05_B2_UW63_M3.wav to preprocess/M05/M05_B2_UW63_M3.wav
# Copying preprocess-failed-2/M05/M05_B1_CW6_M3.wav to preprocess/M05/M05_B1_CW6_M3.wav
# Copying preprocess-failed-2/M05/M05_B3_UW86_M2.wav to preprocess/M05/M05_B3_UW86_M2.wav
# Copying preprocess-failed-2/M05/M05_B1_UW50_M6.wav to preprocess/M05/M05_B1_UW50_M6.wav
# Copying preprocess-failed-2/M05/M05_B3_UW51_M5.wav to preprocess/M05/M05_B3_UW51_M5.wav
# Copying preprocess-failed-2/M05/M05_B1_D2_M6.wav to preprocess/M05/M05_B1_D2_M6.wav
# Copying preprocess-failed-2/M05/M05_B1_LW_M6.wav to preprocess/M05/M05_B1_LW_M6.wav
# Copying preprocess-failed-2/M05/M05_B1_D2_M8.wav to preprocess/M05/M05_B1_D2_M8.wav
# Copying preprocess-failed-2/M05/M05_B1_LO_M4.wav to preprocess/M05/M05_B1_LO_M4.wav
# Copying preprocess-failed-2/M05/M05_B2_UW45_M6.wav to preprocess/M05/M05_B2_UW45_M6.wav
# Copying preprocess-failed-2/M05/M05_B2_UW81_M3.wav to preprocess/M05/M05_B2_UW81_M3.wav
# Copying preprocess-failed-2/M05/M05_B2_UW71_M2.wav to preprocess/M05/M05_B2_UW71_M2.wav
# Copying preprocess-failed-2/M05/M05_B2_UW64_M2.wav to preprocess/M05/M05_B2_UW64_M2.wav
# Copying preprocess-failed-2/M05/M05_B1_UW4_M5.wav to preprocess/M05/M05_B1_UW4_M5.wav
# Copying preprocess-failed-2/M05/M05_B1_CW10_M3.wav to preprocess/M05/M05_B1_CW10_M3.wav
# Copying preprocess-failed-2/M05/M05_B1_LP_M2.wav to preprocess/M05/M05_B1_LP_M2.wav
# Copying preprocess-failed-2/M05/M05_B3_C8_M2.wav to preprocess/M05/M05_B3_C8_M2.wav
# Copying preprocess-failed-2/M05/M05_B1_D8_M4.wav to preprocess/M05/M05_B1_D8_M4.wav
# Copying preprocess-failed-2/M05/M05_B1_UW23_M7.wav to preprocess/M05/M05_B1_UW23_M7.wav
# Copying preprocess-failed-2/M05/M05_B2_CW15_M4.wav to preprocess/M05/M05_B2_CW15_M4.wav
# Copying preprocess-failed-2/M05/M05_B2_UW30_M8.wav to preprocess/M05/M05_B2_UW30_M8.wav
# Copying preprocess-failed-2/M05/M05_B2_LQ_M8.wav to preprocess/M05/M05_B2_LQ_M8.wav
# Copying preprocess-failed-2/M05/M05_B1_C11_M8.wav to preprocess/M05/M05_B1_C11_M8.wav
# Copying preprocess-failed-2/M05/M05_B1_CW86_M2.wav to preprocess/M05/M05_B1_CW86_M2.wav
# Copying preprocess-failed-2/M05/M05_B2_CW33_M8.wav to preprocess/M05/M05_B2_CW33_M8.wav
# Copying preprocess-failed-2/M05/M05_B1_UW34_M2.wav to preprocess/M05/M05_B1_UW34_M2.wav
# Copying preprocess-failed-2/M05/M05_B1_UW48_M7.wav to preprocess/M05/M05_B1_UW48_M7.wav
# Copying preprocess-failed-2/M05/M05_B3_CW99_M8.wav to preprocess/M05/M05_B3_CW99_M8.wav
# Copying preprocess-failed-2/M05/M05_B2_CW21_M4.wav to preprocess/M05/M05_B2_CW21_M4.wav
# Copying preprocess-failed-2/M05/M05_B1_UW41_M7.wav to preprocess/M05/M05_B1_UW41_M7.wav
# Copying preprocess-failed-2/M05/M05_B1_LO_M7.wav to preprocess/M05/M05_B1_LO_M7.wav
# Copying preprocess-failed-2/M05/M05_B2_LX_M2.wav to preprocess/M05/M05_B2_LX_M2.wav
# Copying preprocess-failed-2/M05/M05_B1_UW4_M6.wav to preprocess/M05/M05_B1_UW4_M6.wav
# Copying preprocess-failed-2/M05/M05_B1_C4_M3.wav to preprocess/M05/M05_B1_C4_M3.wav
# Copying preprocess-failed-2/M05/M05_B1_UW35_M6.wav to preprocess/M05/M05_B1_UW35_M6.wav
# Copying preprocess-failed-2/M05/M05_B3_UW34_M3.wav to preprocess/M05/M05_B3_UW34_M3.wav
# Copying preprocess-failed-2/M05/M05_B2_CW7_M2.wav to preprocess/M05/M05_B2_CW7_M2.wav
# Copying preprocess-failed-2/M05/M05_B1_UW51_M4.wav to preprocess/M05/M05_B1_UW51_M4.wav
# Copying preprocess-failed-2/M05/M05_B2_UW1_M7.wav to preprocess/M05/M05_B2_UW1_M7.wav

# %%
dir = "preprocess"
files = []
durations = []
for p in os.listdir(dir):
    for f in os.listdir(f"{dir}/{p}"):
        durations.append(AudioSegment.from_file(f"{dir}/{p}/{f}").duration_seconds)
        files.append(f)
np.histogram(durations, bins=[0,1,2,3,4,5,10,20], range=None)
# Out:
# (array([61291, 71722,  6391,  1355,   385,   262,    20]),
#  array([ 0,  1,  2,  3,  4,  5, 10, 20]))

# %%
len(files)
# Out:
# 141426

# %%
dir = "audio/noisereduce"
files = []
durations = []
for p in os.listdir(dir):
    for f in os.listdir(f"{dir}/{p}"):
        durations.append(AudioSegment.from_file(f"{dir}/{p}/{f}").duration_seconds)
        files.append(f)
np.histogram(durations, bins=[0,1,2,3,4,5,10,20], range=None)
# Out:
# ---------------------------------------------------------------------------
# CouldntDecodeError                        Traceback (most recent call last)
# Cell In[59], line 6
#       4 for p in os.listdir(dir):
#       5     for f in os.listdir(f"{dir}/{p}"):
# ----> 6         durations.append(AudioSegment.from_file(f"{dir}/{p}/{f}").duration_seconds)
#       7         files.append(f)
#       8 np.histogram(durations, bins=[0,1,2,3,4,5,10,20], range=None)
#
# File ~/.conda/envs/speech/lib/python3.9/site-packages/pydub/audio_segment.py:773, in AudioSegment.from_file(cls, file, format, codec, parameters, start_second, duration, **kwargs)
#     771     if close_file:
#     772         file.close()
# --> 773     raise CouldntDecodeError(
#     774         "Decoding failed. ffmpeg returned error code: {0}\n\nOutput from ffmpeg/avlib:\n\n{1}".format(
#     775             p.returncode, p_err.decode(errors='ignore') ))
#     777 p_out = bytearray(p_out)
#     778 fix_wav_headers(p_out)
#
# CouldntDecodeError: Decoding failed. ffmpeg returned error code: 1
#
# Output from ffmpeg/avlib:
#
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# audio/noisereduce/CM12/._CM12_B1_C2_M8.wav: Invalid data found when processing input
